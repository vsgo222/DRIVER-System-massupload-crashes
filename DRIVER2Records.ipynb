# %%
import json, requests, pprint
import pandas as pd

headers = {
    'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
}

params = (
    ('archived', 'False'),
    ('details_only', 'False'),
    ('limit', '5500'),
    ('occurred_max', '2019-09-15T23:59:59.999Z'),
    ('occurred_min', '2016-01-01T00:00:00.001Z'),
    ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e')
)

response = requests.get(
    'https://mumbai.roadsafety.io/api/records/',
    headers=headers,
    params=params,
    verify=False)

binary = response.content

_output = json.loads(binary)

df = pd.read_json(json.dumps(_output['results']))

df.to_csv(r"C:\Users\Vedant\Desktop\DRIVER2Records\fetched_data.csv",index = None, header=True)
# Out:
# C:\Users\Vedant\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
import json, requests, pprint
import pandas as pd
import os
import os.path
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
# Python program to show time by process_time()  
from time import process_time
#check if the files already exists in the folder
import pathlib
from pandas.io.json import json_normalize


def get_headers():
    headers = {
        'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
    }
    return headers


def get_parameters():
    params = (
        ('archived', 'False'), ('details_only', 'False'), ('limit', '6000'), 
        ('occurred_max', '2019-10-20T23:59:59.999Z'), ('occurred_min', '2016-01-01T00:00:00.001Z'),
        ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e')
    )
    

def fetch_data(token, dir):
    response = requests.get('https://mumbai.roadsafety.io/api/records/', headers=get_headers(), params=get_params(), verify=False)
    binary = response.content
    _output = json.loads(binary)
    df = pd.read_json(json.dumps(_output['results']))
    df.to_csv(r'C:\Users\Vedant\Desktop\DRIVER2Records\fetched_data.csv',index = None, header=True)
    pprint.pprint(output)
    
def flatten_json(y):
    out = {}
    
    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[str(name[:-1])] = str(x)
    flatten(y)
    return out

def main(_token, _dir):
    fetch_data(token,dir)
    flatten_data()


if __name__ == '__main__':
        main('cf9a238adf9281773fa6cd5c267b7c13403027c8', r'C:\Users\Vedant\Desktop\DRIVER2Records')

# %%
import json, requests, pprint


def fetch_data():
    response = requests.get('https://mumbai.roadsafety.io/api/records/', headers=get_headers(), params=get_params(), verify=True)
    binary = response.content
    output = json.loads(binary)
    pprint.pprint(output)

def get_headers():
    headers = {'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',}
    return headers


def get_parameters():
    params = (
        ('archived', 'False'), ('details_only', 'False'), ('limit', '5500'), 
        ('occurred_max', '2019-09-15T23:59:59.999Z'), ('occurred_min', '2016-01-01T00:00:00.001Z'),
        ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e')
    )
    


def main(token, dir):
    response = requests.get('https://mumbai.roadsafety.io/api/records/',headers=headers,params=params,verify=False)


if __name__ == '__main__':
        main('cf9a238adf9281773fa6cd5c267b7c13403027c8', 'C:\\Users\\Vedant\\Desktop\\CSV')


headers = {
    'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
}

params = (
    ('archived', 'False'),
    ('details_only', ['True', 'True']),
    ('limit', ['50', '50']),
    #In GMT
    ('occurred_max', ['2019-01-01T18:29:59.999Z']),
    ('occurred_min', ['2015-12-31T18:30:00.000Z']),
    ('record_type', ['1c04abed-f6ef-4ff0-87cd-734fbe4c767e/api/records/?archived=False', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e']),
    ('offset', '4067'),
)

response = requests.get('https://mumbai.roadsafety.io/api/records/', headers=headers, params=params, verify=True)

binary = response.content
output = json.loads(binary)
pprint.pprint(output)

#%%

import json, requests, pprint
import pandas as pd

headers = {
    'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
}

params = (
    ('archived', 'False'),
    ('details_only', 'True'),
    ('limit', '1000'),
    ('occurred_max', '2019-09-15T23:59:59.999Z'),
    ('occurred_min', '2016-01-01T00:00:00.001Z'),
    ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e'),
)

response = requests.get('https://mumbai.roadsafety.io/api/records/', headers=headers, params=params, verify=False)

binary = response.content

# output = json.loads(binary)

# pprint.pprint(output)

df = pd.read_json (binary)

df.info()

#%%

import json, requests, pprint
import pandas as pd

headers = {
    'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
}

params = (
    ('archived', 'False'),
    ('details_only', 'True'),
    ('limit', '1'),
    ('occurred_max', '2019-09-15T23:59:59.999Z'),
    ('occurred_min', '2016-01-01T00:00:00.001Z'),
    ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e'),
)

response = requests.get('https://mumbai.roadsafety.io/api/records/', headers=headers, params=params, verify=False)

binary = response.content

# output = json.loads(binary)

# pprint.pprint(output)

df = pd.read_json(binary)

# print(df.columns)

for index, row in df.head().iterrows():
    print(index, row['results'])

#%%

import json, requests, pprint
import pandas as pd

headers = {
    'Authorization': 'Token cf9a238adf9281773fa6cd5c267b7c13403027c8',
}

params = (
    ('archived', 'False'),
    ('details_only', 'False'),
    ('limit', '5500'),
    ('occurred_max', '2019-09-15T23:59:59.999Z'),
    ('occurred_min', '2016-01-01T00:00:00.001Z'),
    ('record_type', '1c04abed-f6ef-4ff0-87cd-734fbe4c767e')
)

response = requests.get(
    'https://mumbai.roadsafety.io/api/records/',
    headers=headers,
    params=params,
    verify=False)

binary = response.content

_output = json.loads(binary)

df = pd.read_json(json.dumps(_output['results']))

df.to_csv(r"D:\CSV\fetched_data1.csv",index = None, header=True)

#%%
